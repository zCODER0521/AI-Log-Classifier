# %%
import pandas as pd

# %%
df=pd.read_csv('dataset/synthetic_logs.csv')

# %%
df.shape
# Out:
# (2410, 5)

# %%
df.source.unique()
# Out:
# array(['ModernCRM', 'AnalyticsEngine', 'ModernHR', 'BillingSystem',
#        'ThirdPartyAPI', 'LegacyCRM'], dtype=object)

# %%
df.target_label.unique()
# Out:
# array(['HTTP Status', 'Critical Error', 'Security Alert', 'Error',
#        'System Notification', 'Resource Usage', 'User Action',
#        'Workflow Error', 'Deprecation Warning'], dtype=object)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.cluster import DBSCAN 
from sentence_transformers import SentenceTransformer 

model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings= model.encode(df['log_message'].tolist(), show_progress_bar=True)

dbscan=DBSCAN(eps=0.5, min_samples=5, metric='euclidean') 
cluster=dbscan.fit_predict(embeddings) 
df['clusters']=cluster
# Out:
# Batches:   0%|          | 0/76 [00:00<?, ?it/s]

# %%
df[df.clusters==1]
# Out:
#              timestamp           source  \
# 6       3/1/2025 19:14         ModernHR
# 45      5/22/2025 3:17    ThirdPartyAPI
# 98      12/7/2025 8:23        ModernCRM
# 104    6/26/2025 16:19         ModernHR
# 190      3/6/2025 2:08    BillingSystem
# 262      2/2/2025 1:35         ModernHR
# 286     2/5/2025 20:05    ThirdPartyAPI
# 297   11/17/2025 18:21        ModernCRM
# 305    6/14/2025 20:13         ModernHR
# 358    9/20/2025 14:08    ThirdPartyAPI
# 369    11/28/2025 0:59    ThirdPartyAPI
# 417    1/30/2025 13:19    ThirdPartyAPI
# 558    3/17/2025 20:19        ModernCRM
# 672    11/21/2025 8:19         ModernHR
# 724    6/10/2025 15:27    BillingSystem
# 735    11/15/2025 6:29    ThirdPartyAPI
# 828    8/25/2025 12:03        ModernCRM
# 897    6/18/2025 18:10  AnalyticsEngine
# 964     3/14/2025 6:38    BillingSystem
# 969     2/18/2025 4:19    ThirdPartyAPI
# 1026   5/31/2025 18:57         ModernHR
# 1027    9/29/2025 7:47  AnalyticsEngine
# 1161   8/25/2025 19:33         ModernHR
# 1164   7/17/2025 10:59        ModernCRM
# 1190   3/20/2025 23:10    BillingSystem
# 1347    3/31/2025 0:00        ModernCRM
# 1367    4/22/2025 9:00    ThirdPartyAPI
# 1409    4/1/2025 10:58    BillingSystem
# 1511    7/3/2025 21:53         ModernHR
# 1674     4/8/2025 7:20         ModernHR
# 1743    1/6/2025 20:17         ModernHR
# 1774    7/22/2025 7:57  AnalyticsEngine
# 1882   11/10/2025 1:24  AnalyticsEngine
# 1930   3/27/2025 11:58    BillingSystem
# 1944   1/14/2025 12:32    BillingSystem
# 1959     2/8/2025 1:48    ThirdPartyAPI
# 2008   11/4/2025 16:19         ModernHR
# 2120   5/28/2025 23:08    BillingSystem
# 2130     3/7/2025 3:23         ModernHR
# 2180   4/28/2025 20:42        ModernCRM
# 2223    8/25/2025 7:02    ThirdPartyAPI
# 2402    3/13/2025 9:44    BillingSystem
#
#                                             log_message target_label  \
# 6             Shard 6 replication task ended in failure        Error
# 45    Data replication task for shard 14 did not com...        Error
# 98            Data replication task failed for shard 17        Error
# 104              Replication of data to shard 14 failed        Error
# 190   Data replication task for shard 6 did not comp...        Error
# 262   Data replication for shard 13 encountered an i...        Error
# 286      Data replication for shard 16 was unsuccessful        Error
# 297           Shard 2 experienced a replication failure        Error
# 305             Replication error occurred for shard 10        Error
# 358               Replication of data to shard 1 failed        Error
# 369            Data replication task failed for shard 8        Error
# 417       Data replication for shard 2 was unsuccessful        Error
# 558   Data replication for shard 6 encountered an issue        Error
# 672       Data replication for shard 2 was unsuccessful        Error
# 724       Shard 11 data replication task was terminated        Error
# 735                Failed to replicate data for shard 4        Error
# 828                  Error replicating data to shard 17        Error
# 897        Shard 20 data replication was not successful        Error
# 964        Failed data replication attempt for shard 12        Error
# 969        Failed data replication attempt for shard 16        Error
# 1026       Shard 1 data replication task was terminated        Error
# 1027              Replication of data to shard 9 failed        Error
# 1161      Shard 12 data replication task was terminated        Error
# 1164            Replication error occurred for shard 14        Error
# 1190        Shard 1 data replication was not successful        Error
# 1347       Shard 12 data replication was not successful        Error
# 1367        Failed data replication attempt for shard 3        Error
# 1409                  Data replication issue on shard 3        Error
# 1511                  Error replicating data to shard 2        Error
# 1674                  Error replicating data to shard 1        Error
# 1743              Failed to replicate data for shard 13        Error
# 1774              Failed to replicate data for shard 18        Error
# 1882          Shard 4 replication task ended in failure        Error
# 1930                 Data replication issue on shard 13        Error
# 1944  Data replication for shard 8 encountered an issue        Error
# 1959                 Data replication issue on shard 15        Error
# 2008         Shard 18 replication task ended in failure        Error
# 2120  Data replication task for shard 4 did not comp...        Error
# 2130          Shard 4 experienced a replication failure        Error
# 2180         Shard 14 experienced a replication failure        Error
# 2223           Data replication task failed for shard 1        Error
# 2402            Replication error occurred for shard 10        Error
#
#      complexity  clusters
# 6          bert         1
# 45         bert         1
# 98         bert         1
# 104        bert         1
# 190        bert         1
# 262        bert         1
# 286        bert         1
# 297        bert         1
# 305        bert         1
# 358        bert         1
# 369        bert         1
# 417        bert         1
# 558        bert         1
# 672        bert         1
# 724        bert         1
# 735        bert         1
# 828        bert         1
# 897        bert         1
# 964        bert         1
# 969        bert         1
# 1026       bert         1
# 1027       bert         1
# 1161       bert         1
# 1164       bert         1
# 1190       bert         1
# 1347       bert         1
# 1367       bert         1
# 1409       bert         1
# 1511       bert         1
# 1674       bert         1
# 1743       bert         1
# 1774       bert         1
# 1882       bert         1
# 1930       bert         1
# 1944       bert         1
# 1959       bert         1
# 2008       bert         1
# 2120       bert         1
# 2130       bert         1
# 2180       bert         1
# 2223       bert         1
# 2402       bert         1

# %%
cluster_count= df['clusters'].value_counts() 
large_cluster = cluster_count[cluster_count > 10].index
for cluster in large_cluster:
    print(f"Cluster {cluster}:")
    print(df[df['clusters'] == cluster]['log_message'].head(5).to_string(index=False)) 
    print()
# Out:
# Cluster 0:
# nova.osapi_compute.wsgi.server [req-b9718cd8-f6...
# nova.osapi_compute.wsgi.server [req-4895c258-b2...
# nova.osapi_compute.wsgi.server [req-ee8bc8ba-92...
# nova.osapi_compute.wsgi.server [req-f0bffbc3-5a...
# nova.osapi_compute.wsgi.server [req-2bf7cfee-a2...
#
# Cluster -1:
#     Email service experiencing issues with sending
#          Unauthorized access to data was attempted
#           Email server encountered a sending fault
# Multiple bad login attempts detected on user 85...
# Alert: brute force login attempt from 192.168.8...
#
# Cluster 9:
# nova.metadata.wsgi.server [-] 10.11.21.138,10.1...
# nova.metadata.wsgi.server [req-27e91939-3ba4-4d...
# nova.metadata.wsgi.server [-] 10.11.21.143,10.1...
# nova.metadata.wsgi.server [req-61196723-e034-48...
# nova.metadata.wsgi.server [req-7d3eeb2d-3948-43...
#
# Cluster 7:
# User User685 logged out.
#  User User395 logged in.
#  User User225 logged in.
# User User494 logged out.
#  User User900 logged in.
#
# Cluster 8:
# Backup started at 2025-05-14 07:06:55.
# Backup started at 2025-02-15 20:00:19.
#   Backup ended at 2025-08-08 13:06:23.
# Backup started at 2025-11-14 08:27:43.
# Backup started at 2025-12-09 10:19:11.
#
# Cluster 3:
# nova.compute.claims [req-a07ac654-8e81-416d-bfb...
# nova.compute.claims [req-d6986b54-3735-4a42-907...
# nova.compute.claims [req-d82fab16-60f8-4c9f-bde...
# nova.compute.claims [req-2d658d2c-7eff-414e-a68...
# nova.compute.claims [req-9118475d-6e72-48fa-9de...
#
# Cluster 4:
# Backup completed successfully.
# Backup completed successfully.
# Backup completed successfully.
# Backup completed successfully.
# Backup completed successfully.
#
# Cluster 13:
# System updated to version 3.9.1.
# System updated to version 5.5.4.
# System updated to version 4.7.4.
# System updated to version 3.7.7.
# System updated to version 2.6.2.
#
# Cluster 2:
# File data_6169.csv uploaded successfully by use...
# File data_3847.csv uploaded successfully by use...
# File data_7366.csv uploaded successfully by use...
# File data_1206.csv uploaded successfully by use...
# File data_1503.csv uploaded successfully by use...
#
# Cluster 16:
# Disk cleanup completed successfully.
# Disk cleanup completed successfully.
# Disk cleanup completed successfully.
# Disk cleanup completed successfully.
# Disk cleanup completed successfully.
#
# Cluster 11:
# System reboot initiated by user User243.
# System reboot initiated by user User471.
# System reboot initiated by user User216.
# System reboot initiated by user User639.
# System reboot initiated by user User819.
#
# Cluster 12:
# nova.compute.claims [req-72b4858f-049e-49e1-b31...
# nova.compute.claims [req-5c8f52bd-8e3c-41f0-95a...
# nova.compute.claims [req-d38f479d-9bb9-4276-968...
# nova.compute.claims [req-6a763803-4838-49c7-814...
# nova.compute.claims [req-a07ac654-8e81-416d-bfb...
#
# Cluster 1:
#          Shard 6 replication task ended in failure
# Data replication task for shard 14 did not comp...
#          Data replication task failed for shard 17
#             Replication of data to shard 14 failed
# Data replication task for shard 6 did not complete
#
# Cluster 5:
# Account with ID 5351 created by User634.
# Account with ID 7813 created by User373.
# Account with ID 9827 created by User965.
# Account with ID 2520 created by User546.
# Account with ID 2300 created by User964.
#
# Cluster 15:
#   User 7153 made multiple incorrect login attempts
#   User 8300 made multiple incorrect login attempts
# Multiple incorrect login attempts were made by ...
#      User 9167 experienced repeated login failures
#      User 9131 made multiple failed login attempts
#
# Cluster 17:
# nova.compute.claims [req-868a5460-dbb6-416b-b4c...
# nova.compute.claims [req-29a09cdb-3169-4c40-8bd...
# nova.compute.claims [req-d82fab16-60f8-4c9f-bde...
# nova.compute.claims [req-3d26bc3d-373c-4269-b09...
# nova.compute.claims [req-4b4dd551-26d8-48e2-bd5...
#
# Cluster 20:
# Service health check was not successful because...
# Invalid SSL certificate resulted in a failed se...
# Service health check failure was due to an inva...
# An issue with the SSL certificate caused the se...
# Service health check failure was caused by an e...
#
# Cluster 21:
#  Module X experienced an invalid data format issue
#         Input format mismatch occurred in module X
# Module X reported an error in input format vali...
# Module X failed to process input due to formatt...
# Input data format in module X was invalid or co...
#
# Cluster 18:
# nova.compute.resource_tracker [req-addc1839-2ed...
# nova.compute.resource_tracker [req-addc1839-2ed...
# nova.compute.resource_tracker [req-addc1839-2ed...
# nova.compute.resource_tracker [req-addc1839-2ed...
# nova.compute.resource_tracker [req-addc1839-2ed...
#
# Cluster 6:
# nova.compute.resource_tracker [req-addc1839-2ed...
# nova.compute.resource_tracker [req-addc1839-2ed...
# nova.compute.resource_tracker [req-addc1839-2ed...
# nova.compute.resource_tracker [req-addc1839-2ed...
# nova.compute.resource_tracker [req-addc1839-2ed...
#
# Cluster 14:
#   RAID array suffered multiple hard drive failures
#       RAID array experienced multiple disk crashes
# Multiple hard drive issues in RAID configuratio...
# RAID system detected multiple disk failures and...
# RAID system reported multiple hard drive malfun...
#
# Cluster 25:
#    Email service impacted by sending failure
# Service outage due to email delivery problem
#     Error in email delivery affected service
#    Email service suffered a delivery failure
#      Error in email sending impacted service

# %%
import re 
def classify_with_regex(log_message): 
   regex_patterns={
        r"User User\d+ logged (in|out).": "User Action",
        r"Backup (started|ended) at .*": "System Notification",
        r"Backup completed successfully.": "System Notification",
        r"System updated to version .*": "System Notification",
        r"File .* uploaded successfully by user .*": "System Notification",
        r"Disk cleanup completed successfully.": "System Notification",
        r"System reboot initiated by user .*": "System Notification",
        r"Account with ID .* created by .*": "User Action" 
   }
   for pattern, label in regex_patterns.items():
       if re.search(pattern, log_message,re.IGNORECASE):
           return label  
   return None

# %%
classify_with_regex("hey bro")
# Out:
# 'Unknown'

# %%
df.shape
# Out:
# (2410, 7)

# %%
df['regex_label']=df['log_message'].apply(classify_with_regex)
df[df.regex_label.notnull()]
# Out:
#                 timestamp           source  \
# 0     2025-06-27 07:20:25        ModernCRM
# 1         1/14/2025 23:07        ModernCRM
# 2          1/17/2025 1:29  AnalyticsEngine
# 3     2025-07-12 00:24:16         ModernHR
# 4     2025-06-02 18:25:23    BillingSystem
# ...                   ...              ...
# 2405  2025-08-13 07:29:25         ModernHR
# 2406       1/11/2025 5:32         ModernHR
# 2407  2025-08-03 03:07:47    ThirdPartyAPI
# 2408     11/11/2025 11:52    BillingSystem
# 2409     12/25/2025 13:21  AnalyticsEngine
#
#                                             log_message    target_label  \
# 0     nova.osapi_compute.wsgi.server [req-b9718cd8-f...     HTTP Status
# 1        Email service experiencing issues with sending  Critical Error
# 2             Unauthorized access to data was attempted  Security Alert
# 3     nova.osapi_compute.wsgi.server [req-4895c258-b...     HTTP Status
# 4     nova.osapi_compute.wsgi.server [req-ee8bc8ba-9...     HTTP Status
# ...                                                 ...             ...
# 2405  nova.osapi_compute.wsgi.server [req-96c3ec98-2...     HTTP Status
# 2406  User 3844 account experienced multiple failed ...  Security Alert
# 2407  nova.metadata.wsgi.server [req-b6d4a270-accb-4...     HTTP Status
# 2408      Email service affected by failed transmission  Critical Error
# 2409  Repeated failed login attempts occurred for us...  Security Alert
#
#      complexity  clusters regex_label
# 0          bert         0        None
# 1          bert        -1        None
# 2          bert        -1        None
# 3          bert         0        None
# 4          bert         0        None
# ...         ...       ...         ...
# 2405       bert         0        None
# 2406       bert        -1        None
# 2407       bert         9        None
# 2408       bert        -1        None
# 2409       bert        -1        None
#
# [1910 rows x 7 columns]

# %%
df_non_regex = df[df['regex_label'].isnull()].copy()
df_non_regex.shape
# Out:
# (1910, 7)

# %%
print(df_non_regex['target_label'].value_counts()[df_non_regex['target_label'].value_counts()<=5].index.tolist())
# Out:
# ['Workflow Error', 'Deprecation Warning']

# %%
df_non_legacy=df_non_regex[df_non_regex.source!='LegacyCRM']
df_non_legacy.source.unique()
# Out:
# array(['ModernCRM', 'AnalyticsEngine', 'ModernHR', 'BillingSystem',
#        'ThirdPartyAPI'], dtype=object)

# %%
filtered_embeddings=model.encode(df_non_legacy['log_message'].tolist())
filtered_embeddings[:2]
# Out:
# array([[-1.02939636e-01,  3.35459560e-02, -2.20260601e-02,
#          1.55102054e-03, -9.86922346e-03, -1.78956255e-01,
#         -6.34410083e-02, -6.01761676e-02,  2.81108916e-02,
#          5.99620380e-02, -1.72618516e-02,  1.43366342e-03,
#         -1.49560004e-01,  3.15284659e-03, -5.66030703e-02,
#          2.71685738e-02, -1.49890687e-02, -3.54037620e-02,
#         -3.62936333e-02, -1.45410346e-02, -5.61489491e-03,
#          8.75538811e-02,  4.55120690e-02,  2.50963680e-02,
#          1.00187678e-02,  1.24267181e-02, -1.39923587e-01,
#          7.68696219e-02,  3.14095393e-02, -4.15245723e-03,
#          4.36902978e-02,  1.71250030e-02, -8.00951272e-02,
#          5.74006103e-02,  1.89091843e-02,  8.55262354e-02,
#          3.96398716e-02, -1.34371832e-01, -1.44362194e-03,
#          3.06707015e-03,  1.76854074e-01,  4.44886182e-03,
#         -1.69274993e-02,  2.24266127e-02, -4.35049385e-02,
#          6.09031413e-03, -9.98170767e-03, -6.23973384e-02,
#          1.07372385e-02, -6.04895642e-03, -7.14660808e-02,
#         -8.45801830e-03, -3.18019874e-02, -1.00518383e-01,
#          2.25875556e-04, -1.89341623e-02, -3.17793936e-02,
#          4.00860906e-02,  2.19178423e-02, -2.59528812e-02,
#          5.84525093e-02, -8.12509805e-02,  2.12029088e-02,
#         -5.02687469e-02,  1.32057248e-02,  1.32676074e-03,
#          2.27063056e-02, -3.45793664e-02,  3.91546711e-02,
#          1.63533650e-02,  3.92030925e-02,  2.17154231e-02,
#          5.36603443e-02,  3.62809487e-02, -4.22140062e-02,
#         -2.47226972e-02,  1.90312229e-02,  3.61724198e-02,
#          6.37021065e-02, -3.21583287e-03, -8.50388501e-03,
#          3.94655839e-02,  9.02652461e-03,  1.93095896e-02,
#          6.60718158e-02,  1.02694808e-02, -4.43853885e-02,
#         -1.56523176e-02, -1.55714797e-02,  1.32904490e-02,
#         -1.16108200e-02,  4.21831645e-02, -5.44776656e-02,
#          1.29237220e-01, -2.25756764e-02,  5.26204035e-02,
#         -1.58436559e-02,  9.33164954e-02,  6.38025859e-03,
#         -9.36161261e-03, -6.08876497e-02, -3.27307880e-02,
#         -3.44816931e-02,  3.29973958e-02, -4.79392111e-02,
#         -9.81300995e-02,  2.91164871e-02, -2.70903371e-02,
#          1.81867033e-02, -1.73860360e-02, -4.40371372e-02,
#         -7.97002539e-02,  3.01647596e-02, -6.35260493e-02,
#          1.25963166e-02,  8.50249827e-02, -4.58910577e-02,
#          5.81017397e-02, -2.71001682e-02,  8.42776224e-02,
#         -4.09972593e-02, -3.37656178e-02,  1.02088554e-02,
#         -2.54193228e-02, -1.40610306e-08,  4.94446829e-02,
#         -9.04356688e-02, -6.06710091e-02,  8.29529315e-02,
#         -3.29032466e-02,  4.14910391e-02,  9.99591220e-03,
#          6.96138060e-03,  3.99230607e-03, -3.24333347e-02,
#         -3.14656682e-02, -5.33161722e-02, -3.80913541e-02,
#          1.62077211e-02,  2.45778598e-02, -7.26419687e-02,
#         -6.56893551e-02, -8.23131725e-02, -8.00501108e-02,
#         -5.36649451e-02,  5.60894683e-02, -1.10913385e-02,
#          9.62177233e-04, -1.22690313e-01, -5.13836667e-02,
#          9.96701606e-03,  1.00696161e-02,  1.07073091e-01,
#          1.19758211e-02,  1.00423815e-02, -6.28261939e-02,
#         -7.49697462e-02, -6.34077471e-03, -2.72201560e-02,
#         -1.28096208e-01, -2.62459759e-02, -1.81463845e-02,
#         -9.85360444e-02, -3.02990284e-02, -4.02615033e-02,
#          9.94290784e-02,  5.35999537e-02,  2.74899881e-02,
#         -5.53681841e-03,  8.43571350e-02,  8.35162029e-02,
#          3.74304950e-02,  7.11937100e-02,  2.98903156e-02,
#          2.32728738e-02, -3.62111852e-02,  6.20540082e-02,
#          2.15148497e-02,  5.19732758e-02,  1.45337610e-02,
#         -4.60966080e-02,  5.02554402e-02, -7.27027878e-02,
#          2.92778928e-02,  5.62662855e-02, -3.86355035e-02,
#          1.53831849e-02, -6.23095073e-02, -2.77466308e-02]], dtype=float32)

# %%
from sklearn.model_selection import train_test_split    
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import classification_report
X=filtered_embeddings
y=df_non_legacy['target_label'] 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
report = classification_report(y_test, y_pred)
print(report)
# Out:
#                 precision    recall  f1-score   support
#
# Critical Error       0.97      1.00      0.98        31
#          Error       0.97      0.97      0.97        31
#    HTTP Status       1.00      1.00      1.00       209
# Resource Usage       1.00      1.00      1.00        37
# Security Alert       1.00      0.99      0.99        73
#
#       accuracy                           0.99       381
#      macro avg       0.99      0.99      0.99       381
#   weighted avg       0.99      0.99      0.99       381

# %%
import joblib 
joblib.dump(clf, 'models/log_classifier.joblib')
# Out:
# ['models/log_classifier.joblib']
